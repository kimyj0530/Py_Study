# %% [markdown]
# <a href="https://colab.research.google.com/github/kimyj0530/Py_Study/blob/master/01_%EA%B5%90%ED%86%B5%EC%82%AC%EA%B3%A0%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 시각화 모듈 추가

# %%
#한글 폰트 사용설치
# %config InlineBackend.figure_format = 'retina'
# !apt -qq -y install fonts-nanum
# Out:
# fonts-nanum is already the newest version (20180306-3).
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.

# %%
import matplotlib.pyplot as plt

import matplotlib as mpl
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()

import warnings
warnings.filterwarnings('ignore')

# %%
plt.title('한글')
plt.show()

# %% [markdown]
# # **해결문제**
#
#
# ---
# + 도로교통공단 TAAS 시스템에서 제공하는 교통사고 발생추세 자료를 이용하여 문제를 정의하고 데이터를 분석하시오.
# + 참고사이트 : http://taas.koroad.or.kr/sta/acs/exs/typical.do?menuId=WEB_KMP_OVT_UAS_TAT

# %% [markdown]
# # **pandas**
#
#
# ---
#
#
# ## **파이썬에서 사용하는 데이터분석 라이브러리**
#  + 행과 열로 이루어진 데이터 객체를 만들어 다룰 수 있게 되며 보다 안정적으로 대용량의 데이터들을 처리하는데 매우 편리한 도구
#  + NumPy를 기반으로 구축되었으며 과학 컴퓨팅 환경 내에서 다른 많은 타사 라이브러리와 잘 통합되도록 설계
#  + 많은 기능을 가진 데이터 구조
#    - 다양한 방식으로 색인된 데이터를 다룰 수 있는 기능
#    - 시계열 데이터와 비시계열 데이터를 함께 다룰 수 있는 통합 자료 구조
#    - 누락된 데이터를 유연하게 처리할 수 있는 기능
#    - SQL 같은 일반 데이터베이스처럼 데이터를 합치고 관계연산을 수행하는 기능

# %%
import pandas as pd

# %% [markdown]
# # **판다스 외부 데이터 가져오기**
# + csv 읽기
#  - 한글 파일명을 사용할 경우 : df = pd.read_csv(‘파일명‘, engine='python')
#  - 파일 내용 한글이 깨지는 경우 : df = pd.read_csv(‘파일명‘, engine='python', encoding='cp949')
# >
# ```
# df = pd.read_csv(‘파일명‘)
# ```
#
# + 엑셀 읽기
#  - 한글 파일명을 사용할 경우 : df = pd.read_excel(‘파일명‘)
# >
# ```
# df = pd.read_excel(‘파일명‘)
# ```

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#교통사고 데이터 불러오기

data = pd.read_excel('/content/drive/MyDrive/Middle Python/data/교통사고추세.xlsx')
data
# Out:
#     분석지표     기준년도      2017      2018      2019      2020      2021
# 0   사고건수       전체  216335.0  217148.0  229600.0  209654.0  203130.0
# 1   사고건수     1일평균     592.7     594.9     629.0     572.8     556.5
# 2   사고건수  인구10만명당     420.5     420.5     444.0     404.9     392.0
# 3   사고건수  자동차1만대당      82.2      80.4      83.5      74.2      73.5
# 4   사고건수  1000세대당      10.0       9.9      10.2       9.1       8.7
# 5   사망자수       전체    4185.0    3781.0    3349.0    3081.0    2916.0
# 6   사망자수     1일평균      11.5      10.4       9.2       8.4       8.0
# 7   사망자수  인구10만명당       8.1       7.3       6.5       6.0       5.6
# 8   사망자수  자동차1만대당       1.6       1.4       1.2       1.1       1.1
# 9   사망자수  1000세대당       0.2       0.2       0.1       0.1       0.1
# 10  부상자수       전체  322829.0  323037.0  341712.0  306194.0  291608.0
# 11  부상자수     1일평균     884.5     885.0     936.2     836.6     798.9
# 12  부상자수  인구10만명당     627.5     625.6     660.8     591.3     562.7
# 13  부상자수  자동차1만대당     122.6     119.5     124.3     108.4     105.5
# 14  부상자수  1000세대당      14.9      14.7      15.2      13.3      12.4

# %% [markdown]
# ## 데이터프레임(DataFrame) 살펴보기
# * 데이터프레임의 정보 : **df.info()**
#  - 데이터프레임에 대한 전반적인 정보
#  - 데이터프레임을 구성하는 행과 열의 크기, 컬럼명, 컬럼을 구성하는 값의 자료형 등을 출력
# + 데이터프레임의 크기 확인 : **df.shape 속성**
#  - (행, 열) 크기를 확인하기
#  - 행의 개수 : len(데이터프레임), len(.index), .shape[0]
#  - 열의 개수 : len(.column), .shape[1]
# + 데이터프레임의 원소의 총개수 : **df.size 속성**
# + 데이터프레임 개수 확인 :**df.count()**
#  - Null이 아닌 행의 개수 확인
#  - axis='columns' : Null이 아닌 열의 개수 확인
# * 데이터프레임의 인덱스
#  + 열의 인덱스 : **df.colums**
#  + 행의 인덱스 : **df.index**
#  + **데이터프레임의 인덱스 변경**
#    - 열인덱스 명 변경 : df.column = [열명인덱스]
#    - 열항목 중 하나를 인덱스로 사용 : df.set_index(열명)
#    - 인덱스를 일반 데이터 열로 전환 : df.reset_index()
#    - 데이터프레임의 행/열 인덱스를 새로운 배열로 재지정 : df.reindex([])

# %%
# 데이터프레임 정보 확인
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   분석지표    15 non-null     object
#  1   기준년도    15 non-null     object
#  2   2017    15 non-null     float64
#  3   2018    15 non-null     float64
#  4   2019    15 non-null     float64
#  5   2020    15 non-null     float64
#  6   2021    15 non-null     float64
# dtypes: float64(5), object(2)
# memory usage: 968.0+ bytes

# %%
# 데이터프레임 열인덱스 확인
data.columns
# Out:
# Index(['분석지표', '기준년도', '2017', '2018', '2019', '2020', '2021'], dtype='object')

# %%
data.head(2)
# Out:
#    분석지표  기준년도      2017      2018      2019      2020      2021
# 0  사고건수    전체  216335.0  217148.0  229600.0  209654.0  203130.0
# 1  사고건수  1일평균     592.7     594.9     629.0     572.8     556.5

# %%
# 데이터프레임 열인덱스 변경
data.columns = ['분석지표', '구분', '2017', '2018', '2019', '2020', '2021']
data.columns
# 변경확인
data.head(1)
# Out:
#    분석지표  구분      2017      2018      2019      2020      2021
# 0  사고건수  전체  216335.0  217148.0  229600.0  209654.0  203130.0

# %% [markdown]
# ## **조건에 맞는 자료 추출**
# + df[조건식]
#   + 시리즈.isin([리스트])
#     + 부정은 조건식 앞에 ~
#   + and 연산 : &
#   + or 연산 : |
#   + and 연산이나 or연산인 경우는 반드시 ()로 묶어서 사용

# %%
#구분이 전체인 데이터 추출
df = data[(data['구분'] == '전체')]
df
# Out:
#     분석지표  구분      2017      2018      2019      2020      2021
# 0   사고건수  전체  216335.0  217148.0  229600.0  209654.0  203130.0
# 5   사망자수  전체    4185.0    3781.0    3349.0    3081.0    2916.0
# 10  부상자수  전체  322829.0  323037.0  341712.0  306194.0  291608.0

# %%
#행과 열 전환
df = df.T
df
# Out:
#             0       5         10
# 분석지표      사고건수    사망자수      부상자수
# 구분          전체      전체        전체
# 2017  216335.0  4185.0  322829.0
# 2018  217148.0  3781.0  323037.0
# 2019  229600.0  3349.0  341712.0
# 2020  209654.0  3081.0  306194.0
# 2021  203130.0  2916.0  291608.0

# %%
df.head(3)
# Out:
#             0       5         10
# 분석지표      사고건수    사망자수      부상자수
# 구분          전체      전체        전체
# 2017  216335.0  4185.0  322829.0

# %% [markdown]
# ## **데이터프레임 추출하기**
# + 열자료 가져오기 : df[]
#  + 특정 열 가져오기 : df[열인덱스], df[열인덱스 리스트]
#  + 특정 행 가져오기 : df[시작행인덱스:종료행인덱스]
#
# + 인덱스명으로 특정 항목 가져오기 : df.loc[행인덱스, 열인덱스]
#   * 특정 열 가져오기 : df.loc[:, 열인덱스]
#   * 특정 행 가져오기 : df.loc[행인덱스, :]
#   * 특정 항목 가져오기 : df.loc[행인덱스, 열인덱스]
#
# + 인덱스 위치값으로 특정 항목 가져오기 : df.iloc[행인덱스순서, 열인덱스순서]
#   * 특정 열 가져오기 : df.iloc[:, 열인덱스순서]
#   * 특정 행 가져오기 : df.iloc[행인덱스순서, :]
#   * 특정 항목 가져오기 : df.iloc[행인덱스순서, 열인덱스순서]

# %%
#열명에 해당하는 행자료를 리스트로 만들기
col = list(df.iloc[0, :])
col
# Out:
# ['사고건수', '사망자수', '부상자수']

# %%
#연도별 자료만 가져오기
df = df.iloc[2:, :]
df
# Out:
#             0       5         10
# 2017  216335.0  4185.0  322829.0
# 2018  217148.0  3781.0  323037.0
# 2019  229600.0  3349.0  341712.0
# 2020  209654.0  3081.0  306194.0
# 2021  203130.0  2916.0  291608.0

# %%
#열명 변경
df.columns = col
df
# Out:
#           사고건수    사망자수      부상자수
# 2017  216335.0  4185.0  322829.0
# 2018  217148.0  3781.0  323037.0
# 2019  229600.0  3349.0  341712.0
# 2020  209654.0  3081.0  306194.0
# 2021  203130.0  2916.0  291608.0

# %% [markdown]
# ## 열 추출 및 생성
#  + 특정 열 가져오기 : df[열인덱스], df[열인덱스 리스트]
#  + 새로운 열 생성 : df['새로운열명'] = 시리즈데이터

# %%
#치명율과 부상율 구하기
df['치명률'] = df['사망자수'] / df['사고건수'] * 100
df['부상자율'] = df['부상자수'] / df['사고건수']
df
# Out:
#           사고건수    사망자수      부상자수       치명률      부상자율
# 2017  216335.0  4185.0  322829.0    1.9345  1.492264
# 2018  217148.0  3781.0  323037.0  1.741209  1.487635
# 2019  229600.0  3349.0  341712.0  1.458624  1.488293
# 2020  209654.0  3081.0  306194.0  1.469564  1.460473
# 2021  203130.0  2916.0  291608.0  1.435534  1.435573

# %%
#그래프 그리기
df[['사고건수', '사망자수','부상자수']].plot(marker='o')
plt.title('교통사고 추세', fontsize = 15)
plt.show()

# %%
#그래프 그리기
df[['치명률', '부상자율']].plot.bar()
plt.title('연도별 교통사고 현황')
plt.show()

# %% [markdown]
# # **해결문제**
#
#
# ---
# + 도로교통공단 TAAS 시스템에서 제공하는 자료를 이용하여 자신만의 문제를 정의하고 데이터를 분석하시오.
